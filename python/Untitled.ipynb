# %%
from numpy.core.fromnumeric import mean
from flask import jsonify
import pandas as pd
import numpy as np
import xgboost as xgb
import re
import urllib
from urllib.error import URLError, HTTPError, ContentTooShortError
import json
import time
from flask_logs import LogSetup
from functools import reduce
from play_handler import PlayProcess

processed_data = PlayProcess(gameId=401282614)
processed_data.cfb_pbp()
processed_data.run_processing_pipeline()
# processed_data.run_processing_pipeline()
# tmp_json = processed_data.plays_json.to_json(orient="records")
# jsonified_df = json.loads(tmp_json)
# jsonified_df
# Out:
#      homeScore  scoringPlay  priority  statYardage  awayScore  \
# 0          0.0        False     False            0        0.0
# 1          0.0        False     False           25        0.0
# 2          0.0        False     False           -5        0.0
# 3          0.0        False     False           -2        0.0
# 4          0.0        False     False           15        0.0
# ..         ...          ...       ...          ...        ...
# 189       38.0        False     False            3       38.0
# 190       38.0        False     False           -1       38.0
# 191       38.0        False     False            0       38.0
# 192       38.0        False     False            0       38.0
# 193       38.0         True     False           41       41.0
#
#                 wallclock           modified            id  \
# 0    2021-09-05T23:44:47Z  2021-09-06T02:03Z  4.012826e+17
# 1    2021-09-05T23:45:44Z  2021-09-06T02:03Z  4.012826e+17
# 2    2021-09-05T23:46:06Z  2021-09-06T02:03Z  4.012826e+17
# 3    2021-09-05T23:46:51Z  2021-09-06T02:03Z  4.012826e+17
# 4    2021-09-05T23:47:21Z  2021-09-06T02:03Z  4.012826e+17
# ..                    ...                ...           ...
# 189  2021-09-06T03:20:56Z  2021-09-06T03:30Z  4.012826e+17
# 190  2021-09-06T03:20:56Z  2021-09-06T03:31Z  4.012826e+17
# 191  2021-09-06T03:20:56Z  2021-09-06T03:31Z  4.012826e+17
# 192  2021-09-06T03:20:56Z  2021-09-06T03:32Z  4.012826e+17
# 193  2021-09-06T03:20:56Z  2021-09-06T04:23Z  4.012826e+17
#
#                                                   text  period.number  ...  \
# 0    Parker Grothaus kickoff for 65 yds for a touch...              1  ...
# 1    Jack Coan pass complete to Michael Mayer for 2...              1  ...
# 2    NOTRE DAME Penalty, False Start (Zeke Correll)...              1  ...
# 3    Jack Coan sacked by Jermaine Johnson II for a ...              1  ...
# 4    Jack Coan pass complete to Braden Lenzy for 15...              1  ...
# ..                                                 ...            ...  ...
# 189       Kyren Williams run for 3 yds to the FlaSt 22              5  ...
# 190  Jack Coan pass complete to Michael Mayer for a...              5  ...
# 191     Kyren Williams run for no gain to the FlaSt 23              5  ...
# 192                    Timeout FLORIDA ST, clock 00:00              5  ...
# 193                      Jonathan Doerer 41 yd FG GOOD              5  ...
#
#                pos_unit        def_pos_unit   lead_play_type     sp   play  \
# 0        Kickoff Return     Kickoff Defense   Pass Reception   True   True
# 1               Offense             Defense          Penalty  False   True
# 2               Offense             Defense             Sack  False  False
# 3               Offense             Defense   Pass Reception  False   True
# 4               Offense             Defense   Pass Reception  False   True
# ..                  ...                 ...              ...    ...    ...
# 189             Offense             Defense   Pass Reception  False   True
# 190             Offense             Defense             Rush  False   True
# 191             Offense             Defense          Timeout  False   True
# 192             Offense             Defense  Field Goal Good  False  False
# 193  Field Goal Offense  Field Goal Defense              NaN   True   True
#
#     scrimmage_play change_of_pos_team pos_score_diff_end fumble_lost  \
# 0            False              False                0.0       False
# 1             True              False                0.0       False
# 2            False              False                0.0       False
# 3             True              False                0.0       False
# 4             True              False                0.0       False
# ..             ...                ...                ...         ...
# 189           True              False                0.0       False
# 190           True              False                0.0       False
# 191           True              False                0.0       False
# 192          False              False                0.0       False
# 193          False               True                3.0       False
#
#     fumble_recovered
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 189            False
# 190            False
# 191            False
# 192            False
# 193            False
#
# [190 rows x 214 columns]
